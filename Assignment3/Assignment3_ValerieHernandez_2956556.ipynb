# %%
### Run this cell before continuing. 
library(tidyverse)
library(repr)
library(readxl)
source("tests.R")
source("cleanup.R")
options(repr.matrix.max.rows = 6)

# %%
#Question 1.1
answer1.1 <- "D"
test_1.1()
# Out:
# Test passed 😀
# [1] "Success!"

# %%
#Question 1.2
answer1.2 <- "true"
#never is a strong word, but no the absolute path can never look like a relative
#since the beginning of the absolute would need to include personal file locations
test_1.2()
# Out:
# Test passed 🥇
# [1] "Success!"

# %%
#Question 1.3
A <- 1
B <- 3
C <- 2
D <- 1
E <- 2
F <- 3
#not sure why F marked a keyword
test_1.3()
# Out:
# Test passed 😀
# [1] "Success!"

# %%
#Question 1.4
answer1.4 <- "C"
test_1.4()
# Out:
# Test passed 🥇
# [1] "Success!"

# %%
#Question 1.5
A <- 2
B <- 1
C <- 5
D <- 4
E <- 3
test_1.5()
# Out:
# Test passed 🌈
# [1] "Success!"

# %%
### Run this cell to learn more about the arguments used in read_csv
### Reading over the help file will assist with the next question. 

?read_csv

# %%
#Question 2.1
G <- 2
H <- 3
I <- 1
J <- 4
test_2.1()
# Out:
# Test passed 🥇
# [1] "Success!"

# %%
#Question 2.2
answer2.2 <- "true"
# read_csv2 reads files that use ';' automatically, but read_delim would need the delim arg
#to be set to ';' in order to do so
test_2.2()
# Out:
# Test passed 🌈
# [1] "Success!"

# %%
#Question 2.3
answer2.3 <- "B"
test_2.3()
# Out:
# ── Warning (???): Solution is incorrect ────────────────────────────────────────
# `is_true()` is deprecated. Please use `expect_true()` instead.
# Backtrace:
#  1. testthat::expect_that(exists("answer2.3"), is_true())
#  2. testthat (local) condition(object)
#
# [1] "Success!"

# %%
#Question 3.1
answer3.1 <- "C"
test_3.1()
# Out:
# Test passed 😸
# [1] "Success!"

# %%
#Question 3.2
answer3.2 <- "B"
test_3.2()
# Out:
# Test passed 🥳
# [1] "Success!"

# %%
#Question 3.3
A <- "yes"
B <- "read_csv2"
C <- "tab"
D <- "yes"
E <- "no"
F <- "read_excel"

test_3.3()
# Out:
# Test passed 🎉
# [1] "Success!"

# %%
#Question 3.4
happiness_report_path <- "data/happiness_report.csv"
happiness_report <- read_csv(file = happiness_report_path)
print(happiness_report, n = 10)
test_3.4()
# Out:
# Rows: 155 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): country
# dbl (4): happiness_score, GDP_per_capita, life_expectancy, freedom
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# # A tibble: 155 × 5
#    country     happiness_score GDP_per_capita life_expectancy freedom
#    <chr>                 <dbl>          <dbl>           <dbl>   <dbl>
#  1 Norway                 7.54           1.62           0.797   0.635
#  2 Denmark                7.52           1.48           0.793   0.626
#  3 Iceland                7.50           1.48           0.834   0.627
#  4 Switzerland            7.49           1.56           0.858   0.620
#  5 Finland                7.47           1.44           0.809   0.618
#  6 Netherlands            7.38           1.50           0.811   0.585
#  7 Canada                 7.32           1.48           0.835   0.611
#  8 New Zealand            7.31           1.41           0.817   0.614
#  9 Sweden                 7.28           1.49           0.831   0.613
# 10 Australia              7.28           1.48           0.844   0.602
# # … with 145 more rows
# Test passed 🥳
# Test passed 🥳
# Test passed 😀
# Test passed 🎊
# Test passed 🎊
# [1] "Success!"

# %%
#Question 3.5
answer3.5 <- "C"
test_3.5()
# Out:
# Test passed 🥳
# [1] "Success!"

# %%
#Question 3.6.1
happy_semi_df <- read_delim(file = "data/happiness_report_semicolon.csv", delim = ";")
happy_semi_df
test_3.6.1()
# Out:
# Rows: 155 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# chr (4): country, GDP_per_capita, life_expectancy, freedom
# num (1): happiness_score
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     country                  happiness_score GDP_per_capita
# 1   Norway                   7.537e+14       1,61646318435669
# 2   Denmark                  7.522e+14       1,48238301277161
# 3   Iceland                  7.504e+14       1,480633020401
# ⋮   ⋮                        ⋮               ⋮
# 153 Tanzania                 3.349e+14       0,511135876178741
# 154 Burundi                  2.905e+14       0,091622568666935
# 155 Central African Republic 2.693e+14       0,0
#     life_expectancy    freedom
# 1   0,796666502952576  0,635422587394714
# 2   0,792565524578094  0,626006722450256
# 3   0,833552122116089  0,627162635326385
# ⋮   ⋮                  ⋮
# 153 0,364509284496307  0,390017777681351
# 154 0,151610791683197  0,0599007532000542
# 155 0,0187726859003305 0,270842045545578
# Test passed 😀
# Test passed 😸
# Test passed 🎉
# [1] "Success!"

# %%
#Question 3.6.2
happy_semi_df2 <- read_csv2(file = "data/happiness_report_semicolon.csv")
happy_semi_df2
test_3.6.2()
# Out:
# ℹ Using "','" as decimal and "'.'" as grouping mark. Use `read_delim()` for more control.
#
# Rows: 155 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# chr (1): country
# dbl (4): happiness_score, GDP_per_capita, life_expectancy, freedom
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     country                  happiness_score GDP_per_capita life_expectancy
# 1   Norway                   7.537           1.616463       0.7966665
# 2   Denmark                  7.522           1.482383       0.7925655
# 3   Iceland                  7.504           1.480633       0.8335521
# ⋮   ⋮                        ⋮               ⋮              ⋮
# 153 Tanzania                 3.349           0.51113588     0.36450928
# 154 Burundi                  2.905           0.09162257     0.15161079
# 155 Central African Republic 2.693           0.00000000     0.01877269
#     freedom
# 1   0.6354226
# 2   0.6260067
# 3   0.6271626
# ⋮   ⋮
# 153 0.39001778
# 154 0.05990075
# 155 0.27084205
# Test passed 😸
# Test passed 😸
# Test passed 😀
# [1] "Success!"

# %%
#Question 3.6.3
happy_tsv <- read_tsv(file = "data/happiness_report.tsv")
happy_tsv
test_3.6.3()
# Out:
# Rows: 155 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: "\t"
# chr (1): country
# dbl (4): happiness_score, GDP_per_capita, life_expectancy, freedom
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     country                  happiness_score GDP_per_capita life_expectancy
# 1   Norway                   7.537           1.616463       0.7966665
# 2   Denmark                  7.522           1.482383       0.7925655
# 3   Iceland                  7.504           1.480633       0.8335521
# ⋮   ⋮                        ⋮               ⋮              ⋮
# 153 Tanzania                 3.349           0.51113588     0.36450928
# 154 Burundi                  2.905           0.09162257     0.15161079
# 155 Central African Republic 2.693           0.00000000     0.01877269
#     freedom
# 1   0.6354226
# 2   0.6260067
# 3   0.6271626
# ⋮   ⋮
# 153 0.39001778
# 154 0.05990075
# 155 0.27084205
# Test passed 🎊
# Test passed 🎉
# Test passed 🎊
# [1] "Success!"

# %%
#Question 3.6.4
happy_metadata <- read_csv(file = "data/happiness_report_metadata.csv", skip = 3)
happy_metadata
test_3.6.4()
# Out:
# Rows: 155 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): country
# dbl (4): happiness_score, GDP_per_capita, life_expectancy, freedom
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     country                  happiness_score GDP_per_capita life_expectancy
# 1   Norway                   7.537           1.616463       0.7966665
# 2   Denmark                  7.522           1.482383       0.7925655
# 3   Iceland                  7.504           1.480633       0.8335521
# ⋮   ⋮                        ⋮               ⋮              ⋮
# 153 Tanzania                 3.349           0.51113588     0.36450928
# 154 Burundi                  2.905           0.09162257     0.15161079
# 155 Central African Republic 2.693           0.00000000     0.01877269
#     freedom
# 1   0.6354226
# 2   0.6260067
# 3   0.6271626
# ⋮   ⋮
# 153 0.39001778
# 154 0.05990075
# 155 0.27084205
# Test passed 🥳
# Test passed 😀
# Test passed 😀
# [1] "Success!"

# %%
#Question 3.6.5
happy_header <- read_csv(file = "data/happiness_report_no_header.csv", col_names = c("country", "happiness_score", "GDP_per_capita", "life_expectancy", "freedom"))
happy_header
test_3.6.5()
# Out:
# Rows: 155 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): country
# dbl (4): happiness_score, GDP_per_capita, life_expectancy, freedom
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     country                  happiness_score GDP_per_capita life_expectancy
# 1   Norway                   7.537           1.616463       0.7966665
# 2   Denmark                  7.522           1.482383       0.7925655
# 3   Iceland                  7.504           1.480633       0.8335521
# ⋮   ⋮                        ⋮               ⋮              ⋮
# 153 Tanzania                 3.349           0.51113588     0.36450928
# 154 Burundi                  2.905           0.09162257     0.15161079
# 155 Central African Republic 2.693           0.00000000     0.01877269
#     freedom
# 1   0.6354226
# 2   0.6260067
# 3   0.6271626
# ⋮   ⋮
# 153 0.39001778
# 154 0.05990075
# 155 0.27084205
# Test passed 🎉
# Test passed 🥇
# Test passed 😸
# [1] "Success!"

# %%
#Question 3.7
happy_xlsx <- read_excel(path = "data/happiness_report.xlsx")
happy_xlsx
test_3.7()
# Out:
#     country                  happiness_score GDP_per_capita life_expectancy
# 1   Norway                   7.537           1.616463       0.7966665
# 2   Denmark                  7.522           1.482383       0.7925655
# 3   Iceland                  7.504           1.480633       0.8335521
# ⋮   ⋮                        ⋮               ⋮              ⋮
# 153 Tanzania                 3.349           0.51113588     0.36450928
# 154 Burundi                  2.905           0.09162257     0.15161079
# 155 Central African Republic 2.693           0.00000000     0.01877269
#     freedom
# 1   0.6354226
# 2   0.6260067
# 3   0.6271626
# ⋮   ⋮
# 153 0.39001778
# 154 0.05990075
# 155 0.27084205
# Test passed 🥳
# Test passed 🎉
# Test passed 🎊
# [1] "Success!"

# %%
#Question 3.8
answer3.8 <- "yes"
test_3.8()
# Out:
# Test passed 😸
# [1] "Success!"

# %%
#Question 3.9
options(repr.plot.width = 8, repr.plot.height = 7)
header_plot <- ggplot(data = happy_header, aes(x = GDP_per_capita, y = life_expectancy)) + 
    geom_point() + 
    xlab("GDP") + 
    ylab("Life Expectancy")

header_plot
test_3.9()
# Out:
# Test passed 🎉
# Test passed 🌈
# Test passed 😀
# ── Warning (???): header_plot should be a scatter plot. ────────────────────────
# `is_true()` is deprecated. Please use `expect_true()` instead.
# Backtrace:
#  1. testthat::expect_that(...)
#  2. testthat (local) condition(object)
#
# ── Warning (???): Labels on the axes should be descriptive and human readable. ──
# `is_false()` is deprecated. Please use `expect_false()` instead.
# Backtrace:
#  1. testthat::expect_that(...)
#  2. testthat (local) condition(object)
#
# ── Warning (???): Labels on the axes should be descriptive and human readable. ──
# `is_false()` is deprecated. Please use `expect_false()` instead.
# Backtrace:
#  1. testthat::expect_that(...)
#  2. testthat (local) condition(object)
#
# [1] "Success!"
# plot without title

# %%
#Question 4.1
answer4.1 <- "false"
test_4.1()
# Out:
# Test passed 🥳
# [1] "Success!"

# %%
#Question 4.2
answer4.2 <- "D"
test_4.2()
# Out:
# Test passed 🌈
# [1] "Success!"

# %%
# Run this cell before continuing.
install.packages("RSQLite")
library(DBI)
library(RSQLite)
library(dbplyr)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘plogr’
#
#
#
# Attaching package: ‘dbplyr’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     ident, sql

# %%
#Question 4.3.1
conn <- dbConnect(RSQLite::SQLite(), 'data/flights_filtered.db')
test_4.3.1()
# Out:
# Test passed 🎉
# Test passed 🎊
# Test passed 🌈
# Test passed 🎉
# [1] "Success!"

# %%
#Question 4.3.2
flights_table_name <- dbListTables(conn)
flights_table_name
test_4.3.2()
# Out:
# [1] "bos_flights"
# Test passed 🥳
# [1] "Success!"

# %%
#Question 4.3.3
flight_data <- tbl(conn, "bos_flights")
test_4.3.3()
# Out:
# Test passed 😸
# Test passed 😀
# ── Warning (???): flight_data does not contain the correct information. ────────
# Missing values are always removed in SQL aggregation functions.
# Use `na.rm = TRUE` to silence this warning
# This warning is displayed once every 8 hours.
# Backtrace:
#   1. testthat::expect_equal(...)
#  29. dbplyr (local) sum(ARRIVAL_DELAY)
#  30. dbplyr:::check_na_rm(na.rm)
#  31. cli::cli_warn(...)
#
# [1] "Success!"

# %%
# Run this cell before continuing.
head(flight_data)
# Out:
# # Source:   SQL [6 x 13]
# # Database: sqlite 3.40.1 [/content/data/flights_filtered.db]
#    YEAR MONTH   DAY DAY_OF_WEEK ORIGIN…¹ DESTI…² DISTA…³ SCHED…⁴ DEPAR…⁵ SCHED…⁶
#   <int> <int> <int>       <int> <chr>    <chr>     <int>   <int>   <dbl>   <int>
# 1  2015     1     1           4 SJU      BOS        1674     330     -14     635
# 2  2015     1     1           4 BOS      MYR         738     510      -4     730
# 3  2015     1     1           4 BOS      MIA        1258     515      -5     843
# 4  2015     1     1           4 BOS      BWI         369     540      -4     721
# 5  2015     1     1           4 ORD      BOS         867     540     -11     856
# 6  2015     1     1           4 BOS      DTW         632     540      -3     803
# # … with 3 more variables: ARRIVAL_DELAY <dbl>, DIVERTED <int>,
# #   CANCELLED <int>, and abbreviated variable names ¹​ORIGIN_AIRPORT,
# #   ²​DESTINATION_AIRPORT, ³​DISTANCE, ⁴​SCHEDULED_DEPARTURE, ⁵​DEPARTURE_DELAY,
# #   ⁶​SCHEDULED_ARRIVAL

# %%
#Question 4.4
delay_data <- filter(flight_data, ORIGIN_AIRPORT=='BOS')
delay_data
# Out:
# # Source:   SQL [?? x 13]
# # Database: sqlite 3.40.1 [/content/data/flights_filtered.db]
#     YEAR MONTH   DAY DAY_OF_WEEK ORIGI…¹ DESTI…² DISTA…³ SCHED…⁴ DEPAR…⁵ SCHED…⁶
#    <int> <int> <int>       <int> <chr>   <chr>     <int>   <int>   <dbl>   <int>
#  1  2015     1     1           4 BOS     MYR         738     510      -4     730
#  2  2015     1     1           4 BOS     MIA        1258     515      -5     843
#  3  2015     1     1           4 BOS     BWI         369     540      -4     721
#  4  2015     1     1           4 BOS     DTW         632     540      -3     803
#  5  2015     1     1           4 BOS     PBI        1197     545       6     910
#  6  2015     1     1           4 BOS     JFK         187     545      -2     702
#  7  2015     1     1           4 BOS     BUF         395     549      -9     725
#  8  2015     1     1           4 BOS     EWR         200     550       2     718
#  9  2015     1     1           4 BOS     DFW        1562     555      -4     930
# 10  2015     1     1           4 BOS     BWI         369     600      -4     745
# # … with more rows, 3 more variables: ARRIVAL_DELAY <dbl>, DIVERTED <int>,
# #   CANCELLED <int>, and abbreviated variable names ¹​ORIGIN_AIRPORT,
# #   ²​DESTINATION_AIRPORT, ³​DISTANCE, ⁴​SCHEDULED_DEPARTURE, ⁵​DEPARTURE_DELAY,
# #   ⁶​SCHEDULED_ARRIVAL

# %%
delay_data <- select(flight_data, ARRIVAL_DELAY, DEPARTURE_DELAY)
delay_data
test_4.4()
#test passed
# Out:
# # Source:   SQL [?? x 2]
# # Database: sqlite 3.40.1 [/content/data/flights_filtered.db]
#    ARRIVAL_DELAY DEPARTURE_DELAY
#            <dbl>           <dbl>
#  1           -16             -14
#  2           -10              -4
#  3             2              -5
#  4           -21              -4
#  5           -33             -11
#  6           -21              -3
#  7            -9               6
#  8           -13              -2
#  9            -6              -9
# 10           -19               2
# # … with more rows
# Test passed 🥇
# ── Failure (???): delay_data has the wrong dimensions ──────────────────────────
# digest(int_round(as_tibble(tally(delay_data))[[1]], 2)) not equal to "c73696e1f5ebc74021271a447e6a027d".
# 1/1 mismatches
# x[1]: "6bf4cc4788963306e4991f74f4edfd06"
# y[1]: "c73696e1f5ebc74021271a447e6a027d"
# Error in `reporter$stop_if_needed()`:
# ! Test failed
# Traceback:
#
# 1. test_4.4()
# 2. test_that("delay_data has the wrong dimensions", {
#  .     expect_equal(digest(int_round(as_tibble(tally(delay_data))[[1]],
#  .         2)), "c73696e1f5ebc74021271a447e6a027d")
#  .     expect_equal(digest(int_round(dim(delay_data)[2], 2)), "2567f3d5adc004a73dc268884026f3bd")
#  . })
# 3. (function (envir)
#  . {
#  .     handlers <- get_handlers(envir)
#  .     errors <- list()
#  .     for (handler in handlers) {
#  .         tryCatch(eval(handler$expr, handler$envir), error = function(e) {
#  .             errors[[length(errors) + 1]] <<- e
#  .         })
#  .     }
#  .     attr(envir, "withr_handlers") <- NULL
#  .     for (error in errors) {
#  .         stop(error)
#  .     }
#  . })(<environment>)

# %%
head(delay_data)
count(delay_data)
# Out:
# # Source:   SQL [6 x 2]
# # Database: sqlite 3.40.1 [/content/data/flights_filtered.db]
#   ARRIVAL_DELAY DEPARTURE_DELAY
#           <dbl>           <dbl>
# 1           -16             -14
# 2           -10              -4
# 3             2              -5
# 4           -21              -4
# 5           -33             -11
# 6           -21              -3
# # Source:   SQL [1 x 1]
# # Database: sqlite 3.40.1 [/content/data/flights_filtered.db]
#        n
#    <int>
# 1 209856

# %%
# Run this cell before continuing.
ggplot(faithful, aes(x = waiting)) + 
    geom_histogram(bins = 40) + 
    xlab("Waiting Time (mins)") + 
    ylab("Count") + 
    theme(text = element_text(size=20))
# Out:
# plot without title

# %%
#Question 4.5
arrival_delay_plot <- ggplot(delay_data, aes(x = ARRIVAL_DELAY/60)) +
    geom_histogram(aes(y = 100 * stat(count) / sum(stat(count))), binwidth = .25, fill = "lightblue",color = 'steelblue') +
    scale_x_continuous(limits = c(-2, 5)) +
     ylab("% of Flights") +
     xlab("Delay (hours)") +
     theme(text = element_text(size=20))
arrival_delay_plot
test_4.5()
# Out:
# Warning message:
# “`stat(count)` was deprecated in ggplot2 3.4.0.
# ℹ Please use `after_stat(count)` instead.”
# Warning message:
# “Removed 365 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# Test passed 🥇
# Test passed 😸
# Test passed 🥇
# Test passed 🌈
# [1] "Success!"
# plot without title

# %%
#Question 4.6
departure_delay_plot <- ggplot(delay_data, aes(x = DEPARTURE_DELAY/60)) +
    geom_histogram(aes(y = 100 * stat(count) / sum(stat(count))), binwidth = .25, fill = "lightblue",color = 'steelblue') +
    scale_x_continuous(limits = c(-2, 5)) +
     ylab("% of Flights") +
     xlab("Delay (hours)") +
     theme(text = element_text(size=20))
departure_delay_plot
test_4.6()
# Out:
# Warning message:
# “Removed 372 rows containing non-finite values (`stat_bin()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_bar()`).”
# Test passed 😀
# Test passed 😀
# Test passed 😀
# Test passed 🥳
# [1] "Success!"
# plot without title

# %%
#Question 4.7
answer4.7 <- "departures"
test_4.7()
# Out:
# Test passed 🥳
# [1] "Success!"

# %%
#Question 4.8.1
answer4.8.1 <- "A"
test_4.8.1()
# Out:
# Test passed 🎉
# [1] "Success!"

# %%
?write_csv

# %%
#Question 4.8.2
delay_dataframe <- collect(delay_data)
write_csv(delay_dataframe, "data/delay_data.csv")
test_4.8.2()
#test passed
# Out:
# Test passed 🌈
# ── Failure (???): The delay_dataframe doesn't have the right data in it ────────
# digest(int_round(sum(delay_dataframe), 2)) not equal to "d142b116cb76f4e5c3fab6e96bd89a22".
# 1/1 mismatches
# x[1]: "931bfbf9d997b571f39dab677c25bd59"
# y[1]: "d142b116cb76f4e5c3fab6e96bd89a22"
# Error in `reporter$stop_if_needed()`:
# ! Test failed
# Traceback:
#
# 1. test_4.8.2()
# 2. test_that("The delay_dataframe doesn't have the right data in it",
#  .     {
#  .         expect_equal(digest(int_round(sum(delay_dataframe), 2)),
#  .             "d142b116cb76f4e5c3fab6e96bd89a22")
#  .     })
# 3. (function (envir)
#  . {
#  .     handlers <- get_handlers(envir)
#  .     errors <- list()
#  .     for (handler in handlers) {
#  .         tryCatch(eval(handler$expr, handler$envir), error = function(e) {
#  .             errors[[length(errors) + 1]] <<- e
#  .         })
#  .     }
#  .     attr(envir, "withr_handlers") <- NULL
#  .     for (error in errors) {
#  .         stop(error)
#  .     }
#  . })(<environment>)

# %%
source("cleanup.R")

# %%
#Question 5.1.0
answer5.1.0 <- "C"
test_5.1.0()
# Out:
# Test passed 🎉
# [1] "Success!"

# %%
#Question 5.1.1
answer5.1.1 <- "C"
test_5.1.1()
# Out:
# Test passed 😀
# [1] "Success!"

# %%
# Run this cell 
library(rvest)
# Out:
# Attaching package: ‘rvest’
#
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding

# %%
#Question 5.2
url <- 'https://en.wikipedia.org/wiki/Gross_world_product'
gwp <- read_html(url)
print(gwp)
test_5.2()
# Out:
# {html_document}
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-disabled vector-feature-page-tools-pinned-disabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" lang="en" dir="ltr">
# [1] <head>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8 ...
# [2] <body class="skin-vector skin-vector-search-vue vector-toc-pinned mediawi ...
# Test passed 🥇
# Test passed 🥇
# Test passed 😀
# [1] "Success!"

# %%
#Question 5.3
# Run this cell to create the first column for your data set. 
year <- html_text(html_nodes(gwp, ".wikitable tbody:nth-child(1) td:nth-child(1)"))
head(year)
# Out:
# [1] "2019 CE\n" "2014 CE\n" "2010 CE\n" "2005 CE\n" "2000 CE\n" "1995 CE\n"

# %%
# Run this cell.
# Use stringr library.
library(stringr)
# Replace " AD\n" with nothing.
year <- str_replace_all(string = year, pattern = " AD\n", replacement = "")
print(year)
# Out:
#  [1] "2019 CE\n"       "2014 CE\n"       "2010 CE\n"       "2005 CE\n"
#  [5] "2000 CE\n"       "1995 CE\n"       "1990 CE\n"       "1985 CE\n"
#  [9] "1980 CE\n"       "1975 CE\n"       "1970 CE\n"       "1965 CE\n"
# [13] "1960 CE\n"       "1955 CE\n"       "1950 CE\n"       "1940 CE\n"
# [17] "1930 CE\n"       "1925 CE\n"       "1920 CE\n"       "1900 CE\n"
# [21] "1875 CE\n"       "1850 CE\n"       "1800 CE\n"       "1750 CE\n"
# [25] "1700 CE\n"       "1650 CE\n"       "1600 CE\n"       "1500 CE\n"
# [29] "1400 CE\n"       "1350 CE\n"       "1300 CE\n"       "1250 CE\n"
# [33] "1200 CE\n"       "1100 CE\n"       "1000 CE\n"       "900 CE\n"
# [37] "800 CE\n"        "700 CE\n"        "600 CE\n"        "500 CE\n"
# [41] "400 CE\n"        "350 CE\n"        "200 CE\n"        "14 CE\n"
# [45] "1 CE\n"          "200 BCE\n"       "400 BCE\n"       "500 BCE\n"
# [49] "800 BCE\n"       "1000 BCE\n"      "1600 BCE\n"      "2000 BCE\n"
# [53] "3000 BCE\n"      "4000 BCE\n"      "5000 BCE\n"      "8000 BCE\n"
# [57] "10,000 BCE\n"    "25,000 BCE\n"    "300,000 BCE\n"   "1,000,000 BCE\n"

# %%
# Run this cell to clean up the year data and convert it to a number.
# Use grep to select the lines containing " BC\n" and put a - at the beginning of them.
year[grepl(pattern = " BC\n", x = year)] <- str_replace_all(string = year[grepl(pattern = " BC\n", x = year)], pattern = "^", replacement = "-")

# Replace all commas with nothing.
year <- str_replace_all(string = year, pattern = ",", replacement = "")
# Extract the minus symbol and the numbers.
year <- as.numeric(str_extract(string = year, pattern = "-?[0-9]+"))
print(year)
# Out:
#  [1]    2019    2014    2010    2005    2000    1995    1990    1985    1980
# [10]    1975    1970    1965    1960    1955    1950    1940    1930    1925
# [19]    1920    1900    1875    1850    1800    1750    1700    1650    1600
# [28]    1500    1400    1350    1300    1250    1200    1100    1000     900
# [37]     800     700     600     500     400     350     200      14       1
# [46]     200     400     500     800    1000    1600    2000    3000    4000
# [55]    5000    8000   10000   25000  300000 1000000

# %%
?html_nodes

# %%
#Question 5.4
gwp_value <- html_text(html_nodes(gwp, ".wikitable tbody:nth-child(1) td:nth-child(2)"))
print(gwp_value)
# Out:
#  [1] "87,752.00[6]"
#  [2] "77,868.00[1]"
#  [3] "62,220.00 (est. 41,090 in 1990 U.S. dollars)[7]"
#  [4] "43,070.00 (est. 31,300 in 1990 U.S. dollars)[7]"
#  [5] "41,016.69\n"
#  [6] "33,644.33\n"
#  [7] "27,539.57\n"
#  [8] "22,481.11\n"
#  [9] "18,818.44\n"
# [10] "15,149.42\n"
# [11] "12,137.94\n"
# [12] "9,126.98\n"
# [13] "6,855.25\n"
# [14] "5,430.44\n"
# [15] "4,081.81\n"
# [16] "3,001.36\n"
# [17] "2,253.81\n"
# [18] "2,102.88\n"
# [19] "1,733.67\n"
# [20] "1,102.96\n"
# [21] "568.08\n"
# [22] "359.90\n"
# [23] "175.24\n"
# [24] "128.51\n"
# [25] "99.80\n"
# [26] "81.74\n"
# [27] "77.01\n"
# [28] "58.67\n"
# [29] "44.92\n"
# [30] "40.50\n"
# [31] "32.09\n"
# [32] "35.58\n"
# [33] "37.44\n"
# [34] "39.60\n"
# [35] "35.31\n"
# [36] "31.68\n"
# [37] "25.23\n"
# [38] "23.44\n"
# [39] "20.86\n"
# [40] "19.92\n"
# [41] "18.44\n"
# [42] "17.93\n"
# [43] "18.54\n"
# [44] "17.50\n"
# [45] "18.50\n"
# [46] "17.00\n"
# [47] "16.02\n"
# [48] "13.72\n"
# [49] "9.72\n"
# [50] "6.35\n"
# [51] "4.36\n"
# [52] "3.02\n"
# [53] "1.59\n"
# [54] "0.77\n"
# [55] "0.51\n"
# [56] "0.43\n"
# [57] "0.37\n"
# [58] "0.31\n"
# [59] "0.09\n"
# [60] "0.01\n"

# %%
# Replace all commas with nothing.
gwp_value <- str_replace_all(string = gwp_value, pattern = ",", replacement = "")
# Extract the numbers.
gwp_value <- as.numeric(str_extract(string = gwp_value, pattern = "[0-9]+"))
print(gwp_value)
test_5.4()
# Out:
#  [1] 87752 77868 62220 43070 41016 33644 27539 22481 18818 15149 12137  9126
# [13]  6855  5430  4081  3001  2253  2102  1733  1102   568   359   175   128
# [25]    99    81    77    58    44    40    32    35    37    39    35    31
# [37]    25    23    20    19    18    17    18    17    18    17    16    13
# [49]     9     6     4     3     1     0     0     0     0     0     0     0
# Test passed 😀
# ── Warning (???): gwp_value should be a vector containing characters. ──────────
# `is_true()` is deprecated. Please use `expect_true()` instead.
# Backtrace:
#  1. testthat::expect_that(is.vector(gwp_value), is_true())
#  2. testthat (local) condition(object)
#
# ── Failure (???): gwp_value should be a vector containing characters. ──────────
# class(gwp_value) not equal to "character".
# 1/1 mismatches
# x[1]: "numeric"
# y[1]: "character"
# Error in `reporter$stop_if_needed()`:
# ! Test failed
# Traceback:
#
# 1. test_5.4()
# 2. test_that("gwp_value should be a vector containing characters.",
#  .     {
#  .         expect_that(is.vector(gwp_value), is_true())
#  .         expect_equal(class(gwp_value), "character")
#  .     })
# 3. (function (envir)
#  . {
#  .     handlers <- get_handlers(envir)
#  .     errors <- list()
#  .     for (handler in handlers) {
#  .         tryCatch(eval(handler$expr, handler$envir), error = function(e) {
#  .             errors[[length(errors) + 1]] <<- e
#  .         })
#  .     }
#  .     attr(envir, "withr_handlers") <- NULL
#  .     for (error in errors) {
#  .         stop(error)
#  .     }
#  . })(<environment>)

# %%
#Question 5.5
gwp <- tibble(year, gwp_value)
gwp
test_5.5()
# Out:
#    year    gwp_value
# 1  2019    87752
# 2  2014    77868
# 3  2010    62220
# ⋮  ⋮       ⋮
# 58   25000 0
# 59  300000 0
# 60 1000000 0
# Test passed 🥳
# Test passed 🌈
# ── Warning (???): gwp should contain the columns: year and gwp_value ───────────
# `is_true()` is deprecated. Please use `expect_true()` instead.
# Backtrace:
#  1. testthat::expect_that("year" %in% colnames(gwp), is_true())
#  2. testthat (local) condition(object)
#
# ── Warning (???): gwp should contain the columns: year and gwp_value ───────────
# `is_true()` is deprecated. Please use `expect_true()` instead.
# Backtrace:
#  1. testthat::expect_that("gwp_value" %in% colnames(gwp), is_true())
#  2. testthat (local) condition(object)
#
# [1] "Success!"

# %%
gwp <- mutate(gwp, sqrt_year = sqrt(abs(year)))
gwp <- mutate(gwp, sqrt_year = if_else(year < 0, sqrt_year * -1, sqrt_year))
gwp
# Out:
#    year    gwp_value sqrt_year
# 1  2019    87752     44.93328
# 2  2014    77868     44.87761
# 3  2010    62220     44.83302
# ⋮  ⋮       ⋮         ⋮
# 58   25000 0          158.1139
# 59  300000 0          547.7226
# 60 1000000 0         1000.0000

# %%
#Question 5.6
gwp_historical <- ggplot(gwp, aes(x = sqrt_year, y = gwp_value)) +
    geom_line() +
    scale_y_continuous(trans='log10') +
    scale_x_continuous(breaks = c(-1000, -750, -500, -250, -77.7, 0, 38.7), 
                      labels = c("-1000000", "-562500", "-250000", "-62500", "-5000", "0", "1500")) +
    ylab("GWP") +
    xlab("Year") +
    theme(text = element_text(size=20))


options(repr.plot.width=15, repr.plot.height=7)

gwp_historical
test_5.6()
# Out:
# Warning message:
# “Transformation introduced infinite values in continuous y-axis”
# Test passed 😀
# Test passed 🥇
# Test passed 🎉
# ── Warning (???): gwp_historical should be a line plot. ────────────────────────
# `is_true()` is deprecated. Please use `expect_true()` instead.
# Backtrace:
#  1. testthat::expect_that(...)
#  2. testthat (local) condition(object)
#
# ── Warning (???): Labels on the axes should be descriptive and human readable. ──
# `is_false()` is deprecated. Please use `expect_false()` instead.
# Backtrace:
#  1. testthat::expect_that(...)
#  2. testthat (local) condition(object)
#
# ── Warning (???): Labels on the axes should be descriptive and human readable. ──
# `is_false()` is deprecated. Please use `expect_false()` instead.
# Backtrace:
#  1. testthat::expect_that(...)
#  2. testthat (local) condition(object)
#
# [1] "Success!"
# plot without title

# %%
#Question 5.7
answer5.7 <- "C"
test_5.7()
# Out:
# Test passed 🥇
# [1] "Success!"

# %%
source("cleanup.R")
